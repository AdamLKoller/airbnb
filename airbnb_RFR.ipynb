# %% [markdown]
# <hr style="border:2px solid gray">
#
# # Grid Search for best Hyperparameters
# *Task:* We will search for the best parameters for the `RandomForestRegressor`:
#
# ***Contributors***
# - Adam
#
# <hr style="border:2px solid gray">

# %% [markdown]
# ### Importing modules

# %%
from airbnb_preperation import airbnb_preperation
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
import numpy as np

# %% [markdown]
# ### Importing the prepared data

# %%
Xtrain, ytrain, Xdev, ydev, Xtest, ytest = airbnb_preperation('./Data', keep_outliers=True)

# %% [markdown]
# ### Grid search for best hyperparameters (Random Forest Regression)

# %%
def grid_search_hyper_parmas(X_train, y_train):
    n_estimators = [10, 30, 50, 70, 90]
    max_features = [1.0]
    max_depth = [5, 15]
    max_depth.append(None)
    min_samples_split = [2, 5, 10]
    min_samples_leaf = [16, 64, 256]
    bootstrap = [False]


    param_grid = {'n_estimators': n_estimators,
                  'max_features':max_features,
                  'max_depth':max_depth,
                  'min_samples_split':min_samples_split,
                  'min_samples_leaf':min_samples_leaf,
                  'bootstrap':bootstrap}
    
    print('Training...')
    grid= GridSearchCV(RandomForestRegressor(),
                       param_grid,
                       return_train_score = True,
                       refit = True,
                       verbose =3,
                       n_jobs=1,
                       cv=3)
    grid.fit(X_train, y_train)
    print("Grid searching is done!")
    print("The best score: ", grid.best_score_)
    print("The best hyperparameter:")
    print(grid.best_params_)
    return grid

# %%
# %%time
grid_search_hyper_parmas(Xtrain, ytrain)
# Out:
# Training...
# Fitting 3 folds for each of 135 candidates, totalling 405 fits
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.620, test=0.587) total time=   2.5s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.613, test=0.607) total time=   3.6s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.610, test=0.613) total time=   3.6s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.620, test=0.587) total time=  11.6s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.613, test=0.607) total time=   9.1s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.610, test=0.613) total time=   9.7s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=50;, score=(train=0.620, test=0.587) total time=  12.9s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=50;, score=(train=0.613, test=0.607) total time=  12.4s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=50;, score=(train=0.610, test=0.613) total time=  12.5s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=70;, score=(train=0.620, test=0.587) total time=  18.8s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=70;, score=(train=0.613, test=0.607) total time=  17.6s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=70;, score=(train=0.610, test=0.613) total time=  17.6s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=90;, score=(train=0.620, test=0.587) total time=  22.8s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=90;, score=(train=0.613, test=0.607) total time=  22.8s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=90;, score=(train=0.610, test=0.613) total time=  22.9s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=10;, score=(train=0.620, test=0.587) total time=   2.5s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=10;, score=(train=0.613, test=0.607) total time=   3.0s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=10;, score=(train=0.610, test=0.613) total time=   3.1s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=30;, score=(train=0.620, test=0.587) total time=   8.8s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=30;, score=(train=0.613, test=0.607) total time=   8.2s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=30;, score=(train=0.610, test=0.613) total time=   8.3s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=50;, score=(train=0.620, test=0.587) total time=  13.4s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=50;, score=(train=0.613, test=0.607) total time=  13.2s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=50;, score=(train=0.610, test=0.613) total time=  14.2s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=70;, score=(train=0.620, test=0.587) total time=  20.8s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=70;, score=(train=0.613, test=0.607) total time=  18.4s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=70;, score=(train=0.610, test=0.613) total time=  17.1s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=90;, score=(train=0.620, test=0.587) total time=  21.7s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=90;, score=(train=0.613, test=0.607) total time=  21.7s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=90;, score=(train=0.610, test=0.613) total time=  21.6s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=10;, score=(train=0.620, test=0.587) total time=   2.4s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=10;, score=(train=0.613, test=0.607) total time=   3.2s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=10;, score=(train=0.610, test=0.613) total time=   2.9s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=30;, score=(train=0.620, test=0.587) total time=   8.3s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=30;, score=(train=0.613, test=0.607) total time=   7.5s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=30;, score=(train=0.610, test=0.613) total time=   7.5s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=50;, score=(train=0.620, test=0.587) total time=  12.2s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=50;, score=(train=0.613, test=0.607) total time=  12.5s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=50;, score=(train=0.610, test=0.613) total time=  12.3s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=70;, score=(train=0.620, test=0.587) total time=  16.9s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=70;, score=(train=0.613, test=0.607) total time=  16.9s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=70;, score=(train=0.610, test=0.613) total time=  17.3s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=90;, score=(train=0.620, test=0.587) total time=  22.3s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=90;, score=(train=0.613, test=0.607) total time=  22.6s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=90;, score=(train=0.610, test=0.613) total time=  23.3s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=10;, score=(train=0.619, test=0.589) total time=   2.5s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=10;, score=(train=0.613, test=0.607) total time=   3.1s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=10;, score=(train=0.610, test=0.616) total time=   2.9s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=30;, score=(train=0.619, test=0.589) total time=   8.6s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=30;, score=(train=0.613, test=0.607) total time=   7.6s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=30;, score=(train=0.610, test=0.616) total time=   7.5s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=50;, score=(train=0.619, test=0.589) total time=  12.1s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=50;, score=(train=0.613, test=0.607) total time=  12.3s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=50;, score=(train=0.610, test=0.616) total time=  12.1s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=70;, score=(train=0.619, test=0.589) total time=  16.8s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=70;, score=(train=0.613, test=0.607) total time=  16.8s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=70;, score=(train=0.610, test=0.616) total time=  16.9s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=90;, score=(train=0.619, test=0.589) total time=  21.4s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=90;, score=(train=0.613, test=0.607) total time=  21.7s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=90;, score=(train=0.610, test=0.616) total time=  21.4s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=10;, score=(train=0.619, test=0.589) total time=   2.4s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=10;, score=(train=0.613, test=0.607) total time=   3.0s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=10;, score=(train=0.610, test=0.616) total time=   3.0s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=30;, score=(train=0.619, test=0.589) total time=   8.3s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=30;, score=(train=0.613, test=0.607) total time=   7.5s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=30;, score=(train=0.610, test=0.616) total time=   7.5s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.619, test=0.589) total time=  12.0s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.613, test=0.607) total time=  12.1s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.610, test=0.616) total time=  12.0s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.619, test=0.589) total time=  16.8s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.613, test=0.607) total time=  17.2s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.610, test=0.616) total time=  17.3s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.619, test=0.589) total time=  22.7s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.613, test=0.607) total time=  22.8s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.610, test=0.616) total time=  22.7s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.619, test=0.589) total time=   2.5s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.613, test=0.607) total time=   3.1s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.610, test=0.616) total time=   2.8s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.619, test=0.589) total time=   7.9s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.613, test=0.607) total time=   7.2s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.610, test=0.616) total time=   7.4s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.619, test=0.589) total time=  12.1s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.613, test=0.607) total time=  12.1s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.610, test=0.616) total time=  12.1s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.619, test=0.589) total time=  16.6s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.613, test=0.607) total time=  16.6s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.610, test=0.616) total time=  16.5s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=90;, score=(train=0.619, test=0.589) total time=  21.3s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=90;, score=(train=0.613, test=0.607) total time=  21.2s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=90;, score=(train=0.610, test=0.616) total time=  21.1s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=10;, score=(train=0.603, test=0.567) total time=   2.2s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=10;, score=(train=0.610, test=0.605) total time=   2.6s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=10;, score=(train=0.607, test=0.613) total time=   2.6s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=30;, score=(train=0.603, test=0.567) total time=   7.6s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=30;, score=(train=0.610, test=0.605) total time=   7.1s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=30;, score=(train=0.607, test=0.613) total time=   7.2s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=50;, score=(train=0.603, test=0.567) total time=  11.8s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=50;, score=(train=0.610, test=0.605) total time=  11.5s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=50;, score=(train=0.607, test=0.613) total time=  11.8s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=70;, score=(train=0.603, test=0.567) total time=  16.4s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=70;, score=(train=0.610, test=0.605) total time=  16.6s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=70;, score=(train=0.607, test=0.613) total time=  17.0s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=90;, score=(train=0.603, test=0.567) total time=  21.8s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=90;, score=(train=0.610, test=0.605) total time=  22.0s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=90;, score=(train=0.607, test=0.613) total time=  21.5s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=10;, score=(train=0.603, test=0.567) total time=   2.2s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=10;, score=(train=0.610, test=0.605) total time=   2.4s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=10;, score=(train=0.607, test=0.613) total time=   2.4s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=30;, score=(train=0.603, test=0.567) total time=   7.3s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=30;, score=(train=0.610, test=0.605) total time=   7.2s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=30;, score=(train=0.607, test=0.613) total time=   7.3s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=50;, score=(train=0.603, test=0.567) total time=  11.5s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=50;, score=(train=0.610, test=0.605) total time=  11.5s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=50;, score=(train=0.607, test=0.613) total time=  11.5s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=70;, score=(train=0.603, test=0.567) total time=  16.0s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=70;, score=(train=0.610, test=0.605) total time=  15.9s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=70;, score=(train=0.607, test=0.613) total time=  15.8s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=90;, score=(train=0.603, test=0.567) total time=  20.4s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=90;, score=(train=0.610, test=0.605) total time=  20.3s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=90;, score=(train=0.607, test=0.613) total time=  20.3s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=10;, score=(train=0.603, test=0.567) total time=   2.2s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=10;, score=(train=0.610, test=0.605) total time=   2.2s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=10;, score=(train=0.607, test=0.613) total time=   2.6s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=30;, score=(train=0.603, test=0.567) total time=   7.6s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=30;, score=(train=0.610, test=0.605) total time=   7.1s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=30;, score=(train=0.607, test=0.613) total time=   7.2s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=50;, score=(train=0.603, test=0.567) total time=  11.5s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=50;, score=(train=0.610, test=0.605) total time=  11.7s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=50;, score=(train=0.607, test=0.613) total time=  11.8s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=70;, score=(train=0.603, test=0.567) total time=  16.6s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=70;, score=(train=0.610, test=0.605) total time=  17.3s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=70;, score=(train=0.607, test=0.613) total time=  17.0s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=90;, score=(train=0.603, test=0.567) total time=  22.0s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=90;, score=(train=0.610, test=0.605) total time=  22.2s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=90;, score=(train=0.607, test=0.613) total time=  21.7s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.789, test=0.672) total time=   5.7s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.785, test=0.679) total time=   5.3s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.778, test=0.689) total time=   5.4s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.789, test=0.672) total time=  16.2s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.785, test=0.679) total time=  15.6s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.778, test=0.689) total time=  15.5s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=50;, score=(train=0.789, test=0.672) total time=  26.4s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=50;, score=(train=0.785, test=0.679) total time=  25.5s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=50;, score=(train=0.778, test=0.689) total time=  25.4s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=70;, score=(train=0.789, test=0.672) total time=  36.9s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=70;, score=(train=0.785, test=0.679) total time=  36.4s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=70;, score=(train=0.778, test=0.689) total time=  37.8s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=90;, score=(train=0.789, test=0.672) total time=  51.1s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=90;, score=(train=0.785, test=0.679) total time=  46.8s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=90;, score=(train=0.778, test=0.689) total time=  45.7s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=10;, score=(train=0.789, test=0.672) total time=   6.0s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=10;, score=(train=0.785, test=0.679) total time=   5.4s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=10;, score=(train=0.778, test=0.689) total time=   5.6s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=30;, score=(train=0.789, test=0.672) total time=  16.1s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=30;, score=(train=0.785, test=0.679) total time=  15.5s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=30;, score=(train=0.778, test=0.689) total time=  15.5s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=50;, score=(train=0.789, test=0.672) total time=  26.5s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=50;, score=(train=0.785, test=0.679) total time=  25.9s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=50;, score=(train=0.778, test=0.689) total time=  26.5s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=70;, score=(train=0.789, test=0.672) total time=  39.4s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=70;, score=(train=0.785, test=0.679) total time=  38.4s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=70;, score=(train=0.778, test=0.689) total time=  38.7s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=90;, score=(train=0.789, test=0.672) total time=  47.4s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=90;, score=(train=0.785, test=0.679) total time=  45.4s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=90;, score=(train=0.778, test=0.689) total time=  45.4s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=10;, score=(train=0.789, test=0.672) total time=   5.6s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=10;, score=(train=0.785, test=0.679) total time=   5.5s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=10;, score=(train=0.778, test=0.689) total time=   5.5s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=30;, score=(train=0.789, test=0.672) total time=  16.1s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=30;, score=(train=0.785, test=0.679) total time=  15.8s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=30;, score=(train=0.778, test=0.689) total time=  16.1s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=50;, score=(train=0.789, test=0.672) total time=  28.2s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=50;, score=(train=0.785, test=0.679) total time=  27.9s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=50;, score=(train=0.778, test=0.689) total time=  27.5s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=70;, score=(train=0.789, test=0.672) total time=  40.2s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=70;, score=(train=0.785, test=0.679) total time=  37.6s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=70;, score=(train=0.778, test=0.689) total time=  35.2s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=90;, score=(train=0.789, test=0.672) total time=  47.3s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=90;, score=(train=0.785, test=0.679) total time=  45.4s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=90;, score=(train=0.778, test=0.689) total time=  46.3s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=10;, score=(train=0.718, test=0.661) total time=   4.1s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=10;, score=(train=0.709, test=0.677) total time=   4.3s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=10;, score=(train=0.701, test=0.678) total time=   4.2s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=30;, score=(train=0.718, test=0.661) total time=  13.6s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=30;, score=(train=0.709, test=0.677) total time=  12.5s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=30;, score=(train=0.701, test=0.678) total time=  12.6s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=50;, score=(train=0.718, test=0.661) total time=  22.6s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=50;, score=(train=0.709, test=0.677) total time=  20.8s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=50;, score=(train=0.701, test=0.678) total time=  24.6s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=70;, score=(train=0.718, test=0.661) total time=  45.2s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=70;, score=(train=0.709, test=0.677) total time=  30.8s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=70;, score=(train=0.701, test=0.678) total time=  29.4s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=90;, score=(train=0.718, test=0.661) total time=  36.9s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=90;, score=(train=0.709, test=0.677) total time=  34.3s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=90;, score=(train=0.701, test=0.678) total time=  34.5s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=10;, score=(train=0.718, test=0.661) total time=   4.1s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=10;, score=(train=0.709, test=0.677) total time=   4.4s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=10;, score=(train=0.701, test=0.678) total time=   4.2s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=30;, score=(train=0.718, test=0.661) total time=  13.8s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=30;, score=(train=0.709, test=0.677) total time=  12.4s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=30;, score=(train=0.701, test=0.678) total time=  12.5s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.718, test=0.661) total time=  22.2s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.709, test=0.677) total time=  21.1s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.701, test=0.678) total time=  21.1s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.718, test=0.661) total time=  31.7s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.709, test=0.677) total time=  29.3s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.701, test=0.678) total time=  27.0s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.718, test=0.661) total time=  36.7s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.709, test=0.677) total time=  34.4s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.701, test=0.678) total time=  34.3s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.718, test=0.661) total time=   4.1s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.709, test=0.677) total time=   4.5s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.701, test=0.678) total time=   4.2s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.718, test=0.661) total time=  13.2s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.709, test=0.677) total time=  11.8s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.701, test=0.678) total time=  12.0s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.718, test=0.661) total time=  21.6s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.709, test=0.677) total time=  20.5s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.701, test=0.678) total time=  20.9s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.718, test=0.661) total time=  31.4s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.709, test=0.677) total time=  29.1s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.701, test=0.678) total time=  29.2s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=90;, score=(train=0.718, test=0.661) total time=  36.8s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=90;, score=(train=0.709, test=0.677) total time=  33.9s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=90;, score=(train=0.701, test=0.678) total time=  33.9s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=10;, score=(train=0.644, test=0.606) total time=   3.1s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=10;, score=(train=0.648, test=0.641) total time=   3.2s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=10;, score=(train=0.643, test=0.647) total time=   3.2s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=30;, score=(train=0.644, test=0.606) total time=   9.2s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=30;, score=(train=0.648, test=0.641) total time=   8.6s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=30;, score=(train=0.643, test=0.647) total time=   8.6s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=50;, score=(train=0.644, test=0.606) total time=  14.9s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=50;, score=(train=0.648, test=0.641) total time=  14.1s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=50;, score=(train=0.643, test=0.647) total time=  14.3s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=70;, score=(train=0.644, test=0.606) total time=  21.0s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=70;, score=(train=0.648, test=0.641) total time=  20.7s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=70;, score=(train=0.643, test=0.647) total time=  20.7s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=90;, score=(train=0.644, test=0.606) total time=  27.8s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=90;, score=(train=0.648, test=0.641) total time=  26.9s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=90;, score=(train=0.643, test=0.647) total time=  27.1s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=10;, score=(train=0.644, test=0.606) total time=   3.0s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=10;, score=(train=0.648, test=0.641) total time=   3.3s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=10;, score=(train=0.643, test=0.647) total time=   3.3s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=30;, score=(train=0.644, test=0.606) total time=  10.0s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=30;, score=(train=0.648, test=0.641) total time=   8.9s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=30;, score=(train=0.643, test=0.647) total time=   8.4s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=50;, score=(train=0.644, test=0.606) total time=  14.5s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=50;, score=(train=0.648, test=0.641) total time=  14.2s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=50;, score=(train=0.643, test=0.647) total time=  14.1s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=70;, score=(train=0.644, test=0.606) total time=  20.3s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=70;, score=(train=0.648, test=0.641) total time=  19.4s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=70;, score=(train=0.643, test=0.647) total time=  19.4s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=90;, score=(train=0.644, test=0.606) total time=  25.9s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=90;, score=(train=0.648, test=0.641) total time=  25.3s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=90;, score=(train=0.643, test=0.647) total time=  25.8s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=10;, score=(train=0.644, test=0.606) total time=   2.9s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=10;, score=(train=0.648, test=0.641) total time=   3.2s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=10;, score=(train=0.643, test=0.647) total time=   3.2s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=30;, score=(train=0.644, test=0.606) total time=   9.8s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=30;, score=(train=0.648, test=0.641) total time=   9.3s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=30;, score=(train=0.643, test=0.647) total time=   9.2s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=50;, score=(train=0.644, test=0.606) total time=  15.7s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=50;, score=(train=0.648, test=0.641) total time=  15.5s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=50;, score=(train=0.643, test=0.647) total time=  15.1s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=70;, score=(train=0.644, test=0.606) total time=  21.8s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=70;, score=(train=0.648, test=0.641) total time=  21.1s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=70;, score=(train=0.643, test=0.647) total time=  19.3s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=90;, score=(train=0.644, test=0.606) total time=  25.6s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=90;, score=(train=0.648, test=0.641) total time=  24.8s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=90;, score=(train=0.643, test=0.647) total time=  24.7s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.792, test=0.669) total time=   5.7s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.786, test=0.678) total time=   5.5s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.779, test=0.690) total time=   5.5s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.792, test=0.669) total time=  16.3s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.786, test=0.678) total time=  15.6s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.779, test=0.690) total time=  15.6s
# ...
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=30;, score=(train=0.718, test=0.661) total time=  14.1s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=30;, score=(train=0.709, test=0.677) total time=  12.8s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=30;, score=(train=0.701, test=0.678) total time=  13.2s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=50;, score=(train=0.718, test=0.661) total time=  22.9s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=50;, score=(train=0.709, test=0.677) total time=  20.2s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=50;, score=(train=0.701, test=0.678) total time=  19.2s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=70;, score=(train=0.718, test=0.661) total time=  28.9s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=70;, score=(train=0.709, test=0.677) total time=  26.8s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=70;, score=(train=0.701, test=0.678) total time=  26.7s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=90;, score=(train=0.718, test=0.661) total time=  36.8s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=90;, score=(train=0.709, test=0.677) total time=  35.5s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=90;, score=(train=0.701, test=0.678) total time=  36.2s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=10;, score=(train=0.718, test=0.661) total time=   4.5s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=10;, score=(train=0.709, test=0.677) total time=   4.3s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=10;, score=(train=0.701, test=0.678) total time=   4.6s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=30;, score=(train=0.718, test=0.661) total time=  13.9s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=30;, score=(train=0.709, test=0.677) total time=  12.7s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=30;, score=(train=0.701, test=0.678) total time=  12.8s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.718, test=0.661) total time=  22.4s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.709, test=0.677) total time=  20.9s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.701, test=0.678) total time=  21.4s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.718, test=0.661) total time=  29.3s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.709, test=0.677) total time=  26.9s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.701, test=0.678) total time=  26.9s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.718, test=0.661) total time=  36.6s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.709, test=0.677) total time=  34.5s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.701, test=0.678) total time=  35.3s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.718, test=0.661) total time=   4.3s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.709, test=0.677) total time=   4.3s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.701, test=0.678) total time=   4.3s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.718, test=0.661) total time=  13.9s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.709, test=0.677) total time=  12.5s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.701, test=0.678) total time=  12.7s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.718, test=0.661) total time=  22.5s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.709, test=0.677) total time=  20.9s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.701, test=0.678) total time=  20.9s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.718, test=0.661) total time=  30.7s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.709, test=0.677) total time=  26.2s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.701, test=0.678) total time=  27.0s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=90;, score=(train=0.718, test=0.661) total time=  36.7s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=90;, score=(train=0.709, test=0.677) total time=  34.3s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=90;, score=(train=0.701, test=0.678) total time=  35.0s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=10;, score=(train=0.644, test=0.606) total time=   2.9s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=10;, score=(train=0.648, test=0.641) total time=   3.2s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=10;, score=(train=0.643, test=0.647) total time=   3.2s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=30;, score=(train=0.644, test=0.606) total time=   9.7s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=30;, score=(train=0.648, test=0.641) total time=   9.2s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=30;, score=(train=0.643, test=0.647) total time=   9.1s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=50;, score=(train=0.644, test=0.606) total time=  15.7s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=50;, score=(train=0.648, test=0.641) total time=  15.2s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=50;, score=(train=0.643, test=0.647) total time=  15.1s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=70;, score=(train=0.644, test=0.606) total time=  22.0s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=70;, score=(train=0.648, test=0.641) total time=  21.3s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=70;, score=(train=0.643, test=0.647) total time=  21.3s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=90;, score=(train=0.644, test=0.606) total time=  27.6s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=90;, score=(train=0.648, test=0.641) total time=  24.6s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=90;, score=(train=0.643, test=0.647) total time=  25.2s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=10;, score=(train=0.644, test=0.606) total time=   2.8s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=10;, score=(train=0.648, test=0.641) total time=   3.5s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=10;, score=(train=0.643, test=0.647) total time=   3.6s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=30;, score=(train=0.644, test=0.606) total time=   9.8s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=30;, score=(train=0.648, test=0.641) total time=   8.7s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=30;, score=(train=0.643, test=0.647) total time=   8.8s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=50;, score=(train=0.644, test=0.606) total time=  14.7s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=50;, score=(train=0.648, test=0.641) total time=  14.1s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=50;, score=(train=0.643, test=0.647) total time=  14.1s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=70;, score=(train=0.644, test=0.606) total time=  20.4s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=70;, score=(train=0.648, test=0.641) total time=  19.9s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=70;, score=(train=0.643, test=0.647) total time=  20.5s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=90;, score=(train=0.644, test=0.606) total time=  27.5s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=90;, score=(train=0.648, test=0.641) total time=  26.8s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=90;, score=(train=0.643, test=0.647) total time=  26.9s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=10;, score=(train=0.644, test=0.606) total time=   3.1s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=10;, score=(train=0.648, test=0.641) total time=   3.3s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=10;, score=(train=0.643, test=0.647) total time=   3.3s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=30;, score=(train=0.644, test=0.606) total time=  10.0s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=30;, score=(train=0.648, test=0.641) total time=   9.3s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=30;, score=(train=0.643, test=0.647) total time=   9.4s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=50;, score=(train=0.644, test=0.606) total time=  16.0s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=50;, score=(train=0.648, test=0.641) total time=  15.2s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=50;, score=(train=0.643, test=0.647) total time=  14.8s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=70;, score=(train=0.644, test=0.606) total time=  20.1s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=70;, score=(train=0.648, test=0.641) total time=  19.5s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=70;, score=(train=0.643, test=0.647) total time=  19.3s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=90;, score=(train=0.644, test=0.606) total time=  26.4s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=90;, score=(train=0.648, test=0.641) total time=  25.0s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=90;, score=(train=0.643, test=0.647) total time=  25.1s
# Grid searching is done!
# The best score:  0.6799089439110167
# The best hyperparameter:
# {'bootstrap': False, 'max_depth': 15, 'max_features': 1.0, 'min_samples_leaf': 16, 'min_samples_split': 2, 'n_estimators': 10}
# CPU times: total: 1h 41min 24s
# Wall time: 2h 2min 37s
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=1,
#              param_grid={'bootstrap': [False], 'max_depth': [5, 15, None],
#                          'max_features': [1.0],
#                          'min_samples_leaf': [16, 64, 256],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 30, 50, 70, 90]},
#              return_train_score=True, verbose=3)
