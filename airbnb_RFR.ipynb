# %% [markdown]
# <hr style="border:2px solid gray">
#
# # Grid Search for best Hyperparameters
# *Task:* We will search for the best parameters for the `RandomForestRegressor`:
#
# ***Contributors***
# - Adam
#
# <hr style="border:2px solid gray">

# %% [markdown]
# ### Importing modules

# %%
from airbnb_preperation import airbnb_preperation
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
import numpy as np

# %% [markdown]
# ### Importing the prepared data

# %%
Xtrain, ytrain, Xdev, ydev, Xtest, ytest = airbnb_preperation('./Data', keep_outliers=True)

# %% [markdown]
# ### Grid search for best hyperparameters (Random Forest Regression)

# %%
def grid_search_hyper_parmas(X_train, y_train):
    n_estimators = [10, 30, 50, 70, 90]
    max_features = [1.0]
    max_depth = [5, 15]
    max_depth.append(None)
    min_samples_split = [2, 5, 10]
    min_samples_leaf = [16, 64, 256]
    bootstrap = [False]


    param_grid = {'n_estimators': n_estimators,
                  'max_features':max_features,
                  'max_depth':max_depth,
                  'min_samples_split':min_samples_split,
                  'min_samples_leaf':min_samples_leaf,
                  'bootstrap':bootstrap}
    
    print('Training...')
    grid= GridSearchCV(RandomForestRegressor(),
                       param_grid,
                       return_train_score = True,
                       refit = True,
                       verbose =3,
                       n_jobs=1,
                       cv=3)
    grid.fit(X_train, y_train)
    print("Grid searching is done!")
    print("The best score: ", grid.best_score_)
    print("The best hyperparameter:")
    print(grid.best_params_)
    return grid

# %%
# %%time
grid_search_hyper_parmas(Xtrain, ytrain)
# Out:
# Training...
# Fitting 3 folds for each of 135 candidates, totalling 405 fits
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.628, test=0.608) total time=   5.6s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.623, test=0.624) total time=   4.7s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.628, test=0.617) total time=   6.1s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.628, test=0.608) total time=  10.6s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.623, test=0.624) total time=   8.9s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.628, test=0.617) total time=   8.7s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=50;, score=(train=0.628, test=0.608) total time=  13.8s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=50;, score=(train=0.623, test=0.624) total time=  14.0s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=50;, score=(train=0.628, test=0.617) total time=  14.3s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=70;, score=(train=0.628, test=0.608) total time=  19.7s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=70;, score=(train=0.623, test=0.624) total time=  21.8s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=70;, score=(train=0.628, test=0.617) total time=  20.0s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=90;, score=(train=0.628, test=0.608) total time=  29.3s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=90;, score=(train=0.623, test=0.624) total time=  28.5s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=90;, score=(train=0.628, test=0.617) total time=  27.6s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=10;, score=(train=0.628, test=0.608) total time=   3.1s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=10;, score=(train=0.623, test=0.624) total time=   4.0s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=10;, score=(train=0.628, test=0.617) total time=   4.1s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=30;, score=(train=0.628, test=0.608) total time=  12.3s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=30;, score=(train=0.623, test=0.624) total time=  14.0s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=30;, score=(train=0.628, test=0.617) total time=  15.3s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=50;, score=(train=0.628, test=0.608) total time=  22.1s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=50;, score=(train=0.623, test=0.624) total time=  23.7s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=50;, score=(train=0.628, test=0.617) total time=  28.6s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=70;, score=(train=0.628, test=0.608) total time=  38.3s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=70;, score=(train=0.623, test=0.624) total time=  31.5s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=70;, score=(train=0.628, test=0.617) total time=  26.6s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=90;, score=(train=0.628, test=0.608) total time=  31.3s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=90;, score=(train=0.623, test=0.624) total time=  30.8s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=90;, score=(train=0.628, test=0.617) total time=  31.3s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=10;, score=(train=0.628, test=0.608) total time=   3.6s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=10;, score=(train=0.623, test=0.624) total time=   6.3s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=10;, score=(train=0.628, test=0.617) total time=   3.7s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=30;, score=(train=0.628, test=0.608) total time=  12.7s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=30;, score=(train=0.623, test=0.624) total time=  11.6s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=30;, score=(train=0.628, test=0.617) total time=  11.7s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=50;, score=(train=0.628, test=0.608) total time=  17.3s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=50;, score=(train=0.623, test=0.624) total time=  16.5s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=50;, score=(train=0.628, test=0.617) total time=  16.6s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=70;, score=(train=0.628, test=0.608) total time=  27.9s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=70;, score=(train=0.623, test=0.624) total time=  24.4s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=70;, score=(train=0.628, test=0.617) total time=  32.2s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=90;, score=(train=0.628, test=0.608) total time=  38.2s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=90;, score=(train=0.623, test=0.624) total time=  36.2s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=90;, score=(train=0.628, test=0.617) total time=  32.5s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=10;, score=(train=0.627, test=0.607) total time=   3.7s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=10;, score=(train=0.623, test=0.624) total time=   5.5s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=10;, score=(train=0.627, test=0.617) total time=   5.5s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=30;, score=(train=0.627, test=0.607) total time=  12.1s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=30;, score=(train=0.623, test=0.624) total time=  12.7s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=30;, score=(train=0.627, test=0.617) total time=  11.7s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=50;, score=(train=0.627, test=0.607) total time=  20.2s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=50;, score=(train=0.623, test=0.624) total time=  19.7s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=50;, score=(train=0.627, test=0.617) total time=  22.0s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=70;, score=(train=0.627, test=0.607) total time=  27.0s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=70;, score=(train=0.623, test=0.624) total time=  21.5s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=70;, score=(train=0.627, test=0.617) total time=  19.0s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=90;, score=(train=0.627, test=0.607) total time=  25.9s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=90;, score=(train=0.623, test=0.624) total time=  25.1s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=90;, score=(train=0.627, test=0.617) total time=  22.9s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=10;, score=(train=0.627, test=0.607) total time=   4.8s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=10;, score=(train=0.623, test=0.624) total time=   5.6s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=10;, score=(train=0.627, test=0.617) total time=   3.8s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=30;, score=(train=0.627, test=0.607) total time=  14.7s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=30;, score=(train=0.623, test=0.624) total time=  11.8s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=30;, score=(train=0.627, test=0.617) total time=  11.5s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.627, test=0.607) total time=  18.5s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.623, test=0.624) total time=  19.0s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.627, test=0.617) total time=  18.3s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.627, test=0.607) total time=  25.4s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.623, test=0.624) total time=  25.1s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.627, test=0.617) total time=  25.2s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.627, test=0.607) total time=  32.5s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.623, test=0.624) total time=  35.2s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.627, test=0.617) total time=  32.7s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.627, test=0.607) total time=   3.6s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.623, test=0.624) total time=   5.0s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.627, test=0.617) total time=   4.1s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.627, test=0.607) total time=  12.2s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.623, test=0.624) total time=  11.6s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.627, test=0.617) total time=  11.4s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.627, test=0.607) total time=  18.2s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.623, test=0.624) total time=  15.6s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.627, test=0.617) total time=  15.8s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.627, test=0.607) total time=  18.4s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.623, test=0.624) total time=  17.6s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.627, test=0.617) total time=  17.8s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=90;, score=(train=0.627, test=0.607) total time=  22.3s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=90;, score=(train=0.623, test=0.624) total time=  22.1s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=90;, score=(train=0.627, test=0.617) total time=  22.0s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=10;, score=(train=0.624, test=0.606) total time=   2.5s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=10;, score=(train=0.620, test=0.619) total time=   3.3s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=10;, score=(train=0.624, test=0.616) total time=   3.5s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=30;, score=(train=0.624, test=0.606) total time=   8.9s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=30;, score=(train=0.620, test=0.619) total time=   7.6s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=30;, score=(train=0.624, test=0.616) total time=   7.7s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=50;, score=(train=0.624, test=0.606) total time=  12.1s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=50;, score=(train=0.620, test=0.619) total time=  12.0s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=50;, score=(train=0.624, test=0.616) total time=  12.1s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=70;, score=(train=0.624, test=0.606) total time=  16.6s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=70;, score=(train=0.620, test=0.619) total time=  16.6s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=70;, score=(train=0.624, test=0.616) total time=  16.7s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=90;, score=(train=0.624, test=0.606) total time=  21.2s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=90;, score=(train=0.620, test=0.619) total time=  21.2s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=90;, score=(train=0.624, test=0.616) total time=  25.2s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=10;, score=(train=0.624, test=0.606) total time=   2.7s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=10;, score=(train=0.620, test=0.619) total time=   3.6s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=10;, score=(train=0.624, test=0.616) total time=   3.4s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=30;, score=(train=0.624, test=0.606) total time=   9.2s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=30;, score=(train=0.620, test=0.619) total time=   7.6s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=30;, score=(train=0.624, test=0.616) total time=   7.4s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=50;, score=(train=0.624, test=0.606) total time=  11.8s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=50;, score=(train=0.620, test=0.619) total time=  11.8s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=50;, score=(train=0.624, test=0.616) total time=  11.9s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=70;, score=(train=0.624, test=0.606) total time=  16.6s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=70;, score=(train=0.620, test=0.619) total time=  16.8s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=70;, score=(train=0.624, test=0.616) total time=  16.8s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=90;, score=(train=0.624, test=0.606) total time=  22.1s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=90;, score=(train=0.620, test=0.619) total time=  22.2s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=90;, score=(train=0.624, test=0.616) total time=  22.3s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=10;, score=(train=0.624, test=0.606) total time=   2.3s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=10;, score=(train=0.620, test=0.619) total time=   3.0s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=10;, score=(train=0.624, test=0.616) total time=   3.0s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=30;, score=(train=0.624, test=0.606) total time=   7.5s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=30;, score=(train=0.620, test=0.619) total time=   7.4s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=30;, score=(train=0.624, test=0.616) total time=   7.3s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=50;, score=(train=0.624, test=0.606) total time=  11.8s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=50;, score=(train=0.620, test=0.619) total time=  11.8s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=50;, score=(train=0.624, test=0.616) total time=  11.9s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=70;, score=(train=0.624, test=0.606) total time=  16.0s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=70;, score=(train=0.620, test=0.619) total time=  16.4s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=70;, score=(train=0.624, test=0.616) total time=  16.0s
# [CV 1/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=90;, score=(train=0.624, test=0.606) total time=  20.6s
# [CV 2/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=90;, score=(train=0.620, test=0.619) total time=  20.5s
# [CV 3/3] END bootstrap=False, max_depth=5, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=90;, score=(train=0.624, test=0.616) total time=  21.0s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.793, test=0.685) total time=   5.9s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.787, test=0.696) total time=   5.9s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.790, test=0.691) total time=   5.9s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.793, test=0.685) total time=  16.6s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.787, test=0.696) total time=  16.9s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.790, test=0.691) total time=  17.1s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=50;, score=(train=0.793, test=0.685) total time=  28.1s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=50;, score=(train=0.787, test=0.696) total time=  26.8s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=50;, score=(train=0.790, test=0.691) total time=  25.7s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=70;, score=(train=0.793, test=0.685) total time=  36.0s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=70;, score=(train=0.787, test=0.696) total time=  36.0s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=70;, score=(train=0.790, test=0.691) total time=  36.0s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=90;, score=(train=0.793, test=0.685) total time=  46.5s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=90;, score=(train=0.787, test=0.696) total time=  48.3s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=90;, score=(train=0.790, test=0.691) total time=  49.1s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=10;, score=(train=0.793, test=0.685) total time=   6.0s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=10;, score=(train=0.787, test=0.696) total time=   5.8s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=10;, score=(train=0.790, test=0.691) total time=   5.7s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=30;, score=(train=0.793, test=0.685) total time=  16.0s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=30;, score=(train=0.787, test=0.696) total time=  16.0s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=30;, score=(train=0.790, test=0.691) total time=  15.9s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=50;, score=(train=0.793, test=0.685) total time=  26.1s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=50;, score=(train=0.787, test=0.696) total time=  25.8s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=50;, score=(train=0.790, test=0.691) total time=  25.7s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=70;, score=(train=0.793, test=0.685) total time=  36.1s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=70;, score=(train=0.787, test=0.696) total time=  37.1s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=70;, score=(train=0.790, test=0.691) total time=  38.5s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=90;, score=(train=0.793, test=0.685) total time=  49.6s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=90;, score=(train=0.787, test=0.696) total time=  47.3s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=5, n_estimators=90;, score=(train=0.790, test=0.691) total time=  45.7s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=10;, score=(train=0.793, test=0.685) total time=   5.7s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=10;, score=(train=0.787, test=0.696) total time=   5.7s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=10;, score=(train=0.790, test=0.691) total time=   6.0s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=30;, score=(train=0.793, test=0.685) total time=  15.8s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=30;, score=(train=0.787, test=0.696) total time=  15.8s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=30;, score=(train=0.790, test=0.691) total time=  15.7s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=50;, score=(train=0.793, test=0.685) total time=  25.8s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=50;, score=(train=0.787, test=0.696) total time=  26.5s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=50;, score=(train=0.790, test=0.691) total time=  27.2s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=70;, score=(train=0.793, test=0.685) total time=  39.0s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=70;, score=(train=0.787, test=0.696) total time=  39.3s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=70;, score=(train=0.790, test=0.691) total time=  36.2s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=90;, score=(train=0.793, test=0.685) total time=  45.7s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=90;, score=(train=0.787, test=0.696) total time=  45.8s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=16, min_samples_split=10, n_estimators=90;, score=(train=0.790, test=0.691) total time=  46.3s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=10;, score=(train=0.721, test=0.675) total time=   4.0s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=10;, score=(train=0.709, test=0.690) total time=   5.2s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=10;, score=(train=0.718, test=0.678) total time=   4.2s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=30;, score=(train=0.721, test=0.675) total time=  13.2s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=30;, score=(train=0.709, test=0.690) total time=  12.5s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=30;, score=(train=0.718, test=0.678) total time=  13.2s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=50;, score=(train=0.721, test=0.675) total time=  21.3s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=50;, score=(train=0.709, test=0.690) total time=  21.2s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=50;, score=(train=0.718, test=0.678) total time=  21.3s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=70;, score=(train=0.721, test=0.675) total time=  29.0s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=70;, score=(train=0.709, test=0.690) total time=  26.8s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=70;, score=(train=0.718, test=0.678) total time=  28.5s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=90;, score=(train=0.721, test=0.675) total time=  34.7s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=90;, score=(train=0.709, test=0.690) total time=  35.0s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=2, n_estimators=90;, score=(train=0.718, test=0.678) total time=  36.4s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=10;, score=(train=0.721, test=0.675) total time=   4.0s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=10;, score=(train=0.709, test=0.690) total time=   4.9s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=10;, score=(train=0.718, test=0.678) total time=   4.4s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=30;, score=(train=0.721, test=0.675) total time=  13.4s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=30;, score=(train=0.709, test=0.690) total time=  13.1s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=30;, score=(train=0.718, test=0.678) total time=  13.2s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.721, test=0.675) total time=  21.8s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.709, test=0.690) total time=  21.4s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.718, test=0.678) total time=  21.4s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.721, test=0.675) total time=  29.3s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.709, test=0.690) total time=  27.0s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.718, test=0.678) total time=  28.3s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.721, test=0.675) total time=  35.4s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.709, test=0.690) total time=  34.4s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.718, test=0.678) total time=  36.0s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.721, test=0.675) total time=   3.9s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.709, test=0.690) total time=   4.7s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.718, test=0.678) total time=   4.4s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.721, test=0.675) total time=  13.2s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.709, test=0.690) total time=  13.0s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.718, test=0.678) total time=  13.0s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.721, test=0.675) total time=  21.6s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.709, test=0.690) total time=  21.2s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.718, test=0.678) total time=  21.4s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.721, test=0.675) total time=  30.1s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.709, test=0.690) total time=  29.2s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.718, test=0.678) total time=  27.1s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=90;, score=(train=0.721, test=0.675) total time=  34.7s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=90;, score=(train=0.709, test=0.690) total time=  34.7s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=90;, score=(train=0.718, test=0.678) total time=  35.1s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=10;, score=(train=0.665, test=0.638) total time=   2.7s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=10;, score=(train=0.653, test=0.646) total time=   3.8s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=10;, score=(train=0.658, test=0.645) total time=   3.5s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=30;, score=(train=0.665, test=0.638) total time=   9.7s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=30;, score=(train=0.653, test=0.646) total time=   9.3s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=30;, score=(train=0.658, test=0.645) total time=   9.2s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=50;, score=(train=0.665, test=0.638) total time=  15.1s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=50;, score=(train=0.653, test=0.646) total time=  15.1s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=50;, score=(train=0.658, test=0.645) total time=  15.1s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=70;, score=(train=0.665, test=0.638) total time=  21.1s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=70;, score=(train=0.653, test=0.646) total time=  21.3s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=70;, score=(train=0.658, test=0.645) total time=  21.3s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=90;, score=(train=0.665, test=0.638) total time=  27.5s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=90;, score=(train=0.653, test=0.646) total time=  27.5s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=2, n_estimators=90;, score=(train=0.658, test=0.645) total time=  26.6s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=10;, score=(train=0.665, test=0.638) total time=   2.7s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=10;, score=(train=0.653, test=0.646) total time=   3.5s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=10;, score=(train=0.658, test=0.645) total time=   3.6s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=30;, score=(train=0.665, test=0.638) total time=  10.2s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=30;, score=(train=0.653, test=0.646) total time=   8.7s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=30;, score=(train=0.658, test=0.645) total time=   8.9s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=50;, score=(train=0.665, test=0.638) total time=  14.2s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=50;, score=(train=0.653, test=0.646) total time=  14.3s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=50;, score=(train=0.658, test=0.645) total time=  14.4s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=70;, score=(train=0.665, test=0.638) total time=  20.0s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=70;, score=(train=0.653, test=0.646) total time=  20.0s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=70;, score=(train=0.658, test=0.645) total time=  20.1s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=90;, score=(train=0.665, test=0.638) total time=  26.8s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=90;, score=(train=0.653, test=0.646) total time=  27.4s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=5, n_estimators=90;, score=(train=0.658, test=0.645) total time=  27.6s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=10;, score=(train=0.665, test=0.638) total time=   2.9s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=10;, score=(train=0.653, test=0.646) total time=   3.7s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=10;, score=(train=0.658, test=0.645) total time=   3.9s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=30;, score=(train=0.665, test=0.638) total time=  10.1s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=30;, score=(train=0.653, test=0.646) total time=   9.9s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=30;, score=(train=0.658, test=0.645) total time=   9.8s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=50;, score=(train=0.665, test=0.638) total time=  15.6s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=50;, score=(train=0.653, test=0.646) total time=  14.3s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=50;, score=(train=0.658, test=0.645) total time=  14.2s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=70;, score=(train=0.665, test=0.638) total time=  19.8s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=70;, score=(train=0.653, test=0.646) total time=  19.9s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=70;, score=(train=0.658, test=0.645) total time=  19.8s
# [CV 1/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=90;, score=(train=0.665, test=0.638) total time=  24.9s
# [CV 2/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=90;, score=(train=0.653, test=0.646) total time=  25.8s
# [CV 3/3] END bootstrap=False, max_depth=15, max_features=1.0, min_samples_leaf=256, min_samples_split=10, n_estimators=90;, score=(train=0.658, test=0.645) total time=  26.0s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.795, test=0.686) total time=   5.8s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.789, test=0.696) total time=   5.9s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=10;, score=(train=0.791, test=0.691) total time=   6.0s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.795, test=0.686) total time=  17.2s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.789, test=0.696) total time=  17.2s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=16, min_samples_split=2, n_estimators=30;, score=(train=0.791, test=0.691) total time=  17.0s
# ...
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.721, test=0.675) total time=  27.5s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.709, test=0.690) total time=  24.2s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=50;, score=(train=0.718, test=0.678) total time=  24.6s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.721, test=0.675) total time=  36.9s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.709, test=0.690) total time= 1.2min
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=70;, score=(train=0.718, test=0.678) total time= 1.1min
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.721, test=0.675) total time= 1.6min
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.709, test=0.690) total time= 1.5min
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=5, n_estimators=90;, score=(train=0.718, test=0.678) total time= 1.5min
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.721, test=0.675) total time=  10.9s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.709, test=0.690) total time=  10.8s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=10;, score=(train=0.718, test=0.678) total time=  10.9s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.721, test=0.675) total time=  31.1s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.709, test=0.690) total time=  31.2s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=30;, score=(train=0.718, test=0.678) total time=  30.1s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.721, test=0.675) total time=  24.7s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.709, test=0.690) total time=  21.6s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=50;, score=(train=0.718, test=0.678) total time=  22.8s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.721, test=0.675) total time=  35.8s
# [CV 2/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.709, test=0.690) total time=  29.6s
# [CV 3/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=70;, score=(train=0.718, test=0.678) total time=  34.4s
# [CV 1/3] END bootstrap=False, max_depth=None, max_features=1.0, min_samples_leaf=64, min_samples_split=10, n_estimators=90;, score=(train=0.721, test=0.675) total time=  46.8s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1
#
# c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\airbnb_RFR.ipynb Cell 8 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/kolle/OneDrive/Desktop/ds-420/airbnb/airbnb_RFR.ipynb#X10sZmlsZQ%3D%3D?line=17'>18</a> print('Training...')
#      <a href='vscode-notebook-cell:/c%3A/Users/kolle/OneDrive/Desktop/ds-420/airbnb/airbnb_RFR.ipynb#X10sZmlsZQ%3D%3D?line=18'>19</a> grid= GridSearchCV(RandomForestRegressor(),
#      <a href='vscode-notebook-cell:/c%3A/Users/kolle/OneDrive/Desktop/ds-420/airbnb/airbnb_RFR.ipynb#X10sZmlsZQ%3D%3D?line=19'>20</a>                    param_grid,
#      <a href='vscode-notebook-cell:/c%3A/Users/kolle/OneDrive/Desktop/ds-420/airbnb/airbnb_RFR.ipynb#X10sZmlsZQ%3D%3D?line=20'>21</a>                    return_train_score = True,
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/kolle/OneDrive/Desktop/ds-420/airbnb/airbnb_RFR.ipynb#X10sZmlsZQ%3D%3D?line=23'>24</a>                    n_jobs=1,
#      <a href='vscode-notebook-cell:/c%3A/Users/kolle/OneDrive/Desktop/ds-420/airbnb/airbnb_RFR.ipynb#X10sZmlsZQ%3D%3D?line=24'>25</a>                    cv=3)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/kolle/OneDrive/Desktop/ds-420/airbnb/airbnb_RFR.ipynb#X10sZmlsZQ%3D%3D?line=25'>26</a> grid.fit(X_train, y_train)
#      <a href='vscode-notebook-cell:/c%3A/Users/kolle/OneDrive/Desktop/ds-420/airbnb/airbnb_RFR.ipynb#X10sZmlsZQ%3D%3D?line=26'>27</a> print("Grid searching is done!")
#      <a href='vscode-notebook-cell:/c%3A/Users/kolle/OneDrive/Desktop/ds-420/airbnb/airbnb_RFR.ipynb#X10sZmlsZQ%3D%3D?line=27'>28</a> print("The best score: ", grid.best_score_)
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\sklearn\model_selection\_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\sklearn\model_selection\_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\sklearn\model_selection\_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\joblib\parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\joblib\parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\sklearn\model_selection\_validation.py:729, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     727         estimator.fit(X_train, **fit_params)
#     728     else:
# --> 729         estimator.fit(X_train, y_train, **fit_params)
#     731 except Exception:
#     732     # Note fit time as time until error
#     733     fit_time = time.time() - start_time
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\sklearn\ensemble\_forest.py:456, in BaseForest.fit(self, X, y, sample_weight)
#     445 trees = [
#     446     self._make_estimator(append=False, random_state=random_state)
#     447     for i in range(n_more_estimators)
#     448 ]
#     450 # Parallel loop: we prefer the threading backend as the Cython code
#     451 # for fitting the trees is internally releasing the Python GIL
#     452 # making threading more efficient than multiprocessing in
#     453 # that case. However, for joblib 0.12+ we respect any
#     454 # parallel_backend contexts set at a higher level,
#     455 # since correctness does not rely on using threads.
# --> 456 trees = Parallel(
#     457     n_jobs=self.n_jobs,
#     458     verbose=self.verbose,
#     459     prefer="threads",
#     460 )(
#     461     delayed(_parallel_build_trees)(
#     462         t,
#     463         self.bootstrap,
#     464         X,
#     465         y,
#     466         sample_weight,
#     467         i,
#     468         len(trees),
#     469         verbose=self.verbose,
#     470         class_weight=self.class_weight,
#     471         n_samples_bootstrap=n_samples_bootstrap,
#     472     )
#     473     for i, t in enumerate(trees)
#     474 )
#     476 # Collect newly grown trees
#     477 self.estimators_.extend(trees)
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\joblib\parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\joblib\parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\sklearn\ensemble\_forest.py:190, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     188     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     189 else:
# --> 190     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#     192 return tree
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\sklearn\tree\_classes.py:1320, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1290 @_fit_context(prefer_skip_nested_validation=True)
#    1291 def fit(self, X, y, sample_weight=None, check_input=True):
#    1292     """Build a decision tree regressor from the training set (X, y).
#    1293
#    1294     Parameters
#    (...)
#    1317         Fitted estimator.
#    1318     """
# -> 1320     super()._fit(
#    1321         X,
#    1322         y,
#    1323         sample_weight=sample_weight,
#    1324         check_input=check_input,
#    1325     )
#    1326     return self
#
# File c:\Users\kolle\OneDrive\Desktop\ds-420\airbnb\env\Lib\site-packages\sklearn\tree\_classes.py:443, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     432 else:
#     433     builder = BestFirstTreeBuilder(
#     434         splitter,
#     435         min_samples_split,
#    (...)
#     440         self.min_impurity_decrease,
#     441     )
# --> 443 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     445 if self.n_outputs_ == 1 and is_classifier(self):
#     446     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:
